# %% [markdown]
# # Final country demonstration (Zambia)

# %% [markdown]
# ## Imports

# %%
# imports
import boundarytools
import numpy as np

import json
from urllib.request import urlopen

# %% [markdown]
# ## Load in a set of country boundaries from NaturalEarth and GADM

# %%
# set params
country = 'ZMB' #'TUN' #'BDI' #'BLR' #'LUX' #'CHE'
level = 1
ignore_sources = ['GRID3'] #['geoBoundaries (Open)', 'geoBoundaries (Authoritative)']

# %% [markdown]
# ## Loop all pairs of sources and calculate

# %%
import io

# first get all possible sources
sourcedict = boundarytools.utils.find_geocontrast_sources(country, level)
print('available sources:', sourcedict.keys())

# next loop all pairs of sources
source_maps_matrix = {}
source_results_matrix = {}
for source1,url1 in sourcedict.items():
    if source1 in ignore_sources: continue
    if 'geoBoundaries' in source1:
        url1 = url1.replace('.topojson','.geojson')
        coll1 = boundarytools.utils.load_geojson_url(url1)
    else:
        coll1 = boundarytools.utils.load_topojson_url(url1)
    
    source_maps_row = {}
    source_results_row = {}
    
    for source2,url2 in sourcedict.items():
        if source2 == source1: continue
        if source2 in ignore_sources: continue
        print('')
        print(source1, 'vs', source2)
        if 'geoBoundaries' in source2:
            url2 = url2.replace('.topojson','.geojson')
            coll2 = boundarytools.utils.load_geojson_url(url2)
        else:
            coll2 = boundarytools.utils.load_topojson_url(url2)
        
        # show both dataset boundaries
        boundarytools.utils.show_datasets(coll1, coll2)
        
        # loop features
        mainfeats = coll1['features']
        otherfeats = coll2['features']
        for feat1 in mainfeats:
            #print(feat1['properties'])
            probability_same = boundarytools.compare.probability_feature_same_as_features(feat1, otherfeats)
            feat1['properties']['probability_same'] = probability_same
            print('--> {:.2f}% probability of being the same in source2'.format(probability_same*100))

        # show probabilities on map
        boundarytools.utils.show_dataset({'type':'FeatureCollection', 'features':mainfeats},
                                        color_by='probability_same',
                                        minval=0.0, maxval=1.0)
        fobj = io.BytesIO()
        import matplotlib.pyplot as plt
        plt.savefig(fobj, format='png', bbox_inches="tight")
        plt.show()

        # calc total probability for country
        from shapely.geometry import asShape
        from shapely.ops import cascaded_union
        union = cascaded_union([asShape(feat['geometry']) for feat in mainfeats])
        aggfeat = {'type':'Feature', 'geometry':union.__geo_interface__, 'properties':{}}
        probagg = boundarytools.compare.probabilities_aggregate(mainfeats, aggfeat, 'probability_same')
        print('')
        print('Total country probability that a random point in source1 is the same boundary as in source2:')
        print('--> {:.2f}%'.format(probagg*100))
        
        # add to results matrix row
        source_maps_row[source2] = fobj.getvalue()
        source_results_row[source2] = probagg
        
    # add to results matrix
    source_maps_matrix[source1] = source_maps_row
    source_results_matrix[source1] = source_results_row
# Out:
# GADM v3.4 vs Natural Earth v4.1
# --> 96.63% probability of being the same in source2
# --> 96.22% probability of being the same in source2
# --> 94.97% probability of being the same in source2
# --> 95.98% probability of being the same in source2
# --> 91.40% probability of being the same in source2
# --> 86.20% probability of being the same in source2
# --> 97.50% probability of being the same in source2
# --> 73.52% probability of being the same in source2
# --> 96.99% probability of being the same in source2
# --> 98.01% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 93.14%
#
# GADM v3.4 vs OCHA ROSEA
# --> 79.49% probability of being the same in source2
# --> 94.22% probability of being the same in source2
# --> 92.75% probability of being the same in source2
# --> 93.43% probability of being the same in source2
# --> 79.34% probability of being the same in source2
# --> 94.03% probability of being the same in source2
# --> 97.17% probability of being the same in source2
# --> 93.20% probability of being the same in source2
# --> 62.79% probability of being the same in source2
# --> 97.34% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 89.01%
#
# GADM v3.4 vs UN SALB
# --> 82.24% probability of being the same in source2
# --> 95.42% probability of being the same in source2
# --> 95.69% probability of being the same in source2
# --> 94.68% probability of being the same in source2
# --> 85.71% probability of being the same in source2
# --> 94.73% probability of being the same in source2
# --> 97.52% probability of being the same in source2
# --> 93.48% probability of being the same in source2
# --> 64.33% probability of being the same in source2
# --> 97.78% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 90.30%
#
# GADM v3.4 vs geoBoundaries (Open)
# --> 79.51% probability of being the same in source2
# --> 94.21% probability of being the same in source2
# --> 92.78% probability of being the same in source2
# --> 93.41% probability of being the same in source2
# --> 79.32% probability of being the same in source2
# --> 94.03% probability of being the same in source2
# --> 97.18% probability of being the same in source2
# --> 93.19% probability of being the same in source2
# --> 62.79% probability of being the same in source2
# --> 97.35% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 89.02%
#
# GADM v3.4 vs geoBoundaries (Authoritative)
# --> 82.23% probability of being the same in source2
# --> 95.44% probability of being the same in source2
# --> 95.72% probability of being the same in source2
# --> 94.74% probability of being the same in source2
# --> 85.73% probability of being the same in source2
# --> 94.73% probability of being the same in source2
# --> 97.52% probability of being the same in source2
# --> 93.46% probability of being the same in source2
# --> 64.31% probability of being the same in source2
# --> 97.71% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 90.29%
#
# Natural Earth v4.1 vs GADM v3.4
# --> 78.28% probability of being the same in source2
# --> 95.65% probability of being the same in source2
# --> 83.05% probability of being the same in source2
# --> 92.64% probability of being the same in source2
# --> 98.06% probability of being the same in source2
# --> 96.97% probability of being the same in source2
# --> 96.45% probability of being the same in source2
# --> 95.73% probability of being the same in source2
# --> 96.83% probability of being the same in source2
# --> 95.91% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 92.95%
#
# Natural Earth v4.1 vs OCHA ROSEA
# --> 77.92% probability of being the same in source2
# --> 92.61% probability of being the same in source2
# --> 82.35% probability of being the same in source2
# --> 81.27% probability of being the same in source2
# --> 63.24% probability of being the same in source2
# --> 96.63% probability of being the same in source2
# --> 95.96% probability of being the same in source2
# --> 93.85% probability of being the same in source2
# --> 94.94% probability of being the same in source2
# --> 80.07% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 85.96%
#
# Natural Earth v4.1 vs UN SALB
# --> 78.41% probability of being the same in source2
# --> 95.26% probability of being the same in source2
# --> 82.32% probability of being the same in source2
# --> 86.42% probability of being the same in source2
# --> 64.72% probability of being the same in source2
# --> 96.47% probability of being the same in source2
# --> 96.01% probability of being the same in source2
# --> 94.16% probability of being the same in source2
# --> 94.76% probability of being the same in source2
# --> 82.46% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 86.82%
#
# Natural Earth v4.1 vs geoBoundaries (Open)
# --> 77.92% probability of being the same in source2
# --> 92.62% probability of being the same in source2
# --> 82.35% probability of being the same in source2
# --> 81.23% probability of being the same in source2
# --> 63.24% probability of being the same in source2
# --> 96.64% probability of being the same in source2
# --> 95.95% probability of being the same in source2
# --> 93.85% probability of being the same in source2
# --> 94.97% probability of being the same in source2
# --> 80.09% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 85.97%
#
# Natural Earth v4.1 vs geoBoundaries (Authoritative)
# --> 78.41% probability of being the same in source2
# --> 95.25% probability of being the same in source2
# --> 82.33% probability of being the same in source2
# --> 86.43% probability of being the same in source2
# --> 64.72% probability of being the same in source2
# --> 96.38% probability of being the same in source2
# --> 96.01% probability of being the same in source2
# --> 94.24% probability of being the same in source2
# --> 94.79% probability of being the same in source2
# --> 82.46% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 86.81%
#
# OCHA ROSEA vs GADM v3.4
# --> 70.14% probability of being the same in source2
# --> 95.09% probability of being the same in source2
# --> 92.09% probability of being the same in source2
# --> 92.25% probability of being the same in source2
# --> 69.13% probability of being the same in source2
# --> 93.02% probability of being the same in source2
# --> 96.46% probability of being the same in source2
# --> 95.01% probability of being the same in source2
# --> 77.67% probability of being the same in source2
# --> 97.16% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 88.93%
#
# OCHA ROSEA vs Natural Earth v4.1
# --> 71.10% probability of being the same in source2
# --> 95.21% probability of being the same in source2
# --> 91.29% probability of being the same in source2
# --> 92.91% probability of being the same in source2
# --> 69.88% probability of being the same in source2
# --> 85.03% probability of being the same in source2
# --> 96.29% probability of being the same in source2
# --> 74.15% probability of being the same in source2
# --> 77.45% probability of being the same in source2
# --> 97.50% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 86.05%
#
# OCHA ROSEA vs UN SALB
# --> 96.35% probability of being the same in source2
# --> 96.31% probability of being the same in source2
# --> 94.93% probability of being the same in source2
# --> 96.08% probability of being the same in source2
# --> 80.70% probability of being the same in source2
# --> 97.11% probability of being the same in source2
# --> 98.49% probability of being the same in source2
# --> 98.83% probability of being the same in source2
# --> 96.63% probability of being the same in source2
# --> 98.53% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.80%
#
# OCHA ROSEA vs geoBoundaries (Open)
# --> 99.94% probability of being the same in source2
# --> 99.67% probability of being the same in source2
# --> 99.92% probability of being the same in source2
# --> 99.89% probability of being the same in source2
# --> 99.92% probability of being the same in source2
# --> 100.00% probability of being the same in source2
# --> 99.95% probability of being the same in source2
# --> 99.99% probability of being the same in source2
# --> 99.91% probability of being the same in source2
# --> 99.96% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 99.94%
#
# OCHA ROSEA vs geoBoundaries (Authoritative)
# --> 96.35% probability of being the same in source2
# --> 96.35% probability of being the same in source2
# --> 94.97% probability of being the same in source2
# --> 96.13% probability of being the same in source2
# --> 80.74% probability of being the same in source2
# --> 97.14% probability of being the same in source2
# --> 98.49% probability of being the same in source2
# --> 98.81% probability of being the same in source2
# --> 96.64% probability of being the same in source2
# --> 98.44% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.79%
#
# UN SALB vs GADM v3.4
# --> 71.72% probability of being the same in source2
# --> 96.27% probability of being the same in source2
# --> 93.83% probability of being the same in source2
# --> 93.62% probability of being the same in source2
# --> 80.68% probability of being the same in source2
# --> 94.27% probability of being the same in source2
# --> 96.80% probability of being the same in source2
# --> 95.30% probability of being the same in source2
# --> 78.95% probability of being the same in source2
# --> 97.79% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 90.24%
#
# UN SALB vs Natural Earth v4.1
# --> 72.38% probability of being the same in source2
# --> 95.00% probability of being the same in source2
# --> 92.74% probability of being the same in source2
# --> 93.36% probability of being the same in source2
# --> 80.26% probability of being the same in source2
# --> 86.07% probability of being the same in source2
# --> 96.34% probability of being the same in source2
# --> 74.14% probability of being the same in source2
# --> 78.65% probability of being the same in source2
# --> 97.52% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 86.94%
#
# UN SALB vs OCHA ROSEA
# --> 95.37% probability of being the same in source2
# --> 96.28% probability of being the same in source2
# --> 93.76% probability of being the same in source2
# --> 96.21% probability of being the same in source2
# --> 87.29% probability of being the same in source2
# --> 97.70% probability of being the same in source2
# --> 98.48% probability of being the same in source2
# --> 98.83% probability of being the same in source2
# --> 95.66% probability of being the same in source2
# --> 98.72% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.83%
#
# UN SALB vs geoBoundaries (Open)
# --> 95.35% probability of being the same in source2
# --> 96.46% probability of being the same in source2
# --> 93.78% probability of being the same in source2
# --> 96.20% probability of being the same in source2
# --> 87.26% probability of being the same in source2
# --> 97.70% probability of being the same in source2
# --> 98.49% probability of being the same in source2
# --> 98.84% probability of being the same in source2
# --> 95.64% probability of being the same in source2
# --> 98.72% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.84%
#
# UN SALB vs geoBoundaries (Authoritative)
# --> 99.92% probability of being the same in source2
# --> 99.84% probability of being the same in source2
# --> 99.89% probability of being the same in source2
# --> 99.87% probability of being the same in source2
# --> 99.77% probability of being the same in source2
# --> 99.94% probability of being the same in source2
# --> 99.98% probability of being the same in source2
# --> 99.90% probability of being the same in source2
# --> 99.91% probability of being the same in source2
# --> 99.87% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 99.91%
#
# geoBoundaries (Open) vs GADM v3.4
# --> 70.15% probability of being the same in source2
# --> 95.13% probability of being the same in source2
# --> 92.10% probability of being the same in source2
# --> 92.25% probability of being the same in source2
# --> 69.09% probability of being the same in source2
# --> 93.02% probability of being the same in source2
# --> 96.47% probability of being the same in source2
# --> 95.00% probability of being the same in source2
# --> 77.66% probability of being the same in source2
# --> 97.18% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 88.93%
#
# geoBoundaries (Open) vs Natural Earth v4.1
# --> 71.11% probability of being the same in source2
# --> 95.29% probability of being the same in source2
# --> 91.28% probability of being the same in source2
# --> 92.93% probability of being the same in source2
# --> 69.82% probability of being the same in source2
# --> 85.03% probability of being the same in source2
# --> 96.28% probability of being the same in source2
# --> 74.16% probability of being the same in source2
# --> 77.45% probability of being the same in source2
# --> 97.52% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 86.06%
#
# geoBoundaries (Open) vs OCHA ROSEA
# --> 99.95% probability of being the same in source2
# --> 99.72% probability of being the same in source2
# --> 99.90% probability of being the same in source2
# --> 99.90% probability of being the same in source2
# --> 99.89% probability of being the same in source2
# --> 100.00% probability of being the same in source2
# --> 99.95% probability of being the same in source2
# --> 99.99% probability of being the same in source2
# --> 99.91% probability of being the same in source2
# --> 99.97% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 99.94%
#
# geoBoundaries (Open) vs UN SALB
# --> 96.34% probability of being the same in source2
# --> 96.54% probability of being the same in source2
# --> 94.94% probability of being the same in source2
# --> 96.08% probability of being the same in source2
# --> 80.65% probability of being the same in source2
# --> 97.11% probability of being the same in source2
# --> 98.49% probability of being the same in source2
# --> 98.84% probability of being the same in source2
# --> 96.61% probability of being the same in source2
# --> 98.54% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.80%
#
# geoBoundaries (Open) vs geoBoundaries (Authoritative)
# --> 96.35% probability of being the same in source2
# --> 96.57% probability of being the same in source2
# --> 94.98% probability of being the same in source2
# --> 96.13% probability of being the same in source2
# --> 80.69% probability of being the same in source2
# --> 97.14% probability of being the same in source2
# --> 98.49% probability of being the same in source2
# --> 98.82% probability of being the same in source2
# --> 96.61% probability of being the same in source2
# --> 98.45% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.80%
#
# geoBoundaries (Authoritative) vs GADM v3.4
# --> 71.70% probability of being the same in source2
# --> 96.26% probability of being the same in source2
# --> 93.89% probability of being the same in source2
# --> 93.65% probability of being the same in source2
# --> 80.69% probability of being the same in source2
# --> 94.27% probability of being the same in source2
# --> 96.79% probability of being the same in source2
# --> 95.24% probability of being the same in source2
# --> 78.93% probability of being the same in source2
# --> 97.75% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 90.23%
#
# geoBoundaries (Authoritative) vs Natural Earth v4.1
# --> 72.37% probability of being the same in source2
# --> 95.00% probability of being the same in source2
# --> 92.76% probability of being the same in source2
# --> 93.40% probability of being the same in source2
# --> 80.26% probability of being the same in source2
# --> 86.07% probability of being the same in source2
# --> 96.33% probability of being the same in source2
# --> 74.12% probability of being the same in source2
# --> 78.65% probability of being the same in source2
# --> 97.46% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 86.93%
#
# geoBoundaries (Authoritative) vs OCHA ROSEA
# --> 95.36% probability of being the same in source2
# --> 96.28% probability of being the same in source2
# --> 93.83% probability of being the same in source2
# --> 96.23% probability of being the same in source2
# --> 87.32% probability of being the same in source2
# --> 97.72% probability of being the same in source2
# --> 98.49% probability of being the same in source2
# --> 98.77% probability of being the same in source2
# --> 95.68% probability of being the same in source2
# --> 98.66% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.83%
#
# geoBoundaries (Authoritative) vs UN SALB
# --> 99.91% probability of being the same in source2
# --> 99.80% probability of being the same in source2
# --> 99.93% probability of being the same in source2
# --> 99.84% probability of being the same in source2
# --> 99.75% probability of being the same in source2
# --> 99.93% probability of being the same in source2
# --> 99.98% probability of being the same in source2
# --> 99.86% probability of being the same in source2
# --> 99.92% probability of being the same in source2
# --> 99.90% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 99.91%
#
# geoBoundaries (Authoritative) vs geoBoundaries (Open)
# --> 95.35% probability of being the same in source2
# --> 96.46% probability of being the same in source2
# --> 93.85% probability of being the same in source2
# --> 96.22% probability of being the same in source2
# --> 87.29% probability of being the same in source2
# --> 97.72% probability of being the same in source2
# --> 98.48% probability of being the same in source2
# --> 98.78% probability of being the same in source2
# --> 95.65% probability of being the same in source2
# --> 98.66% probability of being the same in source2
# Total country probability that a random point in source1 is the same boundary as in source2:
# --> 96.83%

# %%
# convert results matrix dicts to list of lists
import base64
sources = source_results_matrix.keys()
table = []
table.append([''] + list(sources))
for source1 in sources:
    row = [source1]
    for source2 in sources:
        if source1 == source2:
            probagg = 1
            imgtag = ''
        else:
            probagg = source_results_matrix[source1][source2]
            imgbytes = source_maps_matrix[source1][source2]
            imgascii = base64.b64encode(imgbytes).decode('ascii')
            imgtag = '<img src="data:image/png;base64,{0}" width="80px">'.format(imgascii)
        probtag = '<span>{:.2f}%</span>'.format(probagg*100)
        cell = imgtag + probtag
        row.append(cell)
    table.append(row)

# show results matrix
print('source similarity/probability matrix for {}-ADM{}'.format(country,level))
from IPython.display import HTML, display
htmlstring = '<table>'
for row in table:
    htmlstring += '<tr>'
    for cell in row:
        htmlstring += '<td style="text-align:center">'
        htmlstring += cell
        htmlstring += '</td>'
    htmlstring += '</tr>'
htmlstring += '</table>'
display(HTML(htmlstring))
# Out:
# source similarity/probability matrix for ZMB-ADM1
# <table><tr><td style="text-align:center"></td><td style="text-align:center">GADM v3.4</td><td style="text-align:center">Natural Earth v4.1</td><td style="text-align:center">OCHA ROSEA</td><td style="text-align:center">UN SALB</td><td style="text-align:center">geoBoundaries (Open)</td><td style="text-align:center">geoBoundaries (Authoritative)</td></tr><tr><td style="text-align:center">GADM v3.4</td><td style="text-align:center"><span>100.00%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>93.14%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>89.01%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>90.30%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>89.02%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>90.29%</span></td></tr><tr><td style="text-align:center">Natural Earth v4.1</td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>92.95%</span></td><td style="text-align:center"><span>100.00%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>85.96%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>86.82%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>85.97%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>86.81%</span></td></tr><tr><td style="text-align:center">OCHA ROSEA</td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>88.93%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>86.05%</span></td><td style="text-align:center"><span>100.00%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>96.80%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>99.94%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>96.79%</span></td></tr><tr><td style="text-align:center">UN SALB</td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>90.24%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>86.94%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>96.83%</span></td><td style="text-align:center"><span>100.00%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>96.84%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>99.91%</span></td></tr><tr><td style="text-align:center">geoBoundaries (Open)</td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>88.93%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>86.06%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>99.94%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>96.80%</span></td><td style="text-align:center"><span>100.00%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>96.80%</span></td></tr><tr><td style="text-align:center">geoBoundaries (Authoritative)</td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>90.23%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>86.93%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>96.83%</span></td><td style="text-align:center"><img src="data:image/png;base64,..." width="80px"><span>99.91%</span></td><td ...
